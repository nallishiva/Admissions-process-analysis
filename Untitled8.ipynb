# %% [markdown]
# <a href="https://colab.research.google.com/github/nallishiva/Admissions-process-analysis/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Identify missing values
#
# ### Subtask:
# Check for missing values in the DataFrame and visualize their distribution.

# %% [markdown]
# **Reasoning**:
# Check for missing values in each column and visualize their distribution.

# %%
print(df.isnull().sum())

import missingno as msno
msno.matrix(df)
# Out:
# ID\tYear_Birth\tEducation\tMarital_Status\tIncome\tKidhome\tTeenhome\tDt_Customer\tRecency\tMntWines\tMntFruits\tMntMeatProducts\tMntFishProducts\tMntSweetProducts\tMntGoldProds\tNumDealsPurchases\tNumWebPurchases\tNumCatalogPurchases\tNumStorePurchases\tNumWebVisitsMonth\tAcceptedCmp3\tAcceptedCmp4\tAcceptedCmp5\tAcceptedCmp1\tAcceptedCmp2\tComplain\tZ_CostContact\tZ_Revenue\tResponse    0
# dtype: int64
# <Axes: >
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# **Reasoning**:
# The missing value check and visualization show that the data is not properly delimited, as all columns are concatenated into a single column. The next step is to load the data correctly using the tab delimiter.

# %%
df = pd.read_csv('/content/marketing_campaign.csv', sep='\t')
print(df.isnull().sum())
import missingno as msno
msno.matrix(df)
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64
# <Axes: >

# %% [markdown]
# ## Handle missing values
#
# ### Subtask:
# Choose an appropriate strategy to handle the missing values (e.g., imputation, dropping rows/columns) and implement it.

# %% [markdown]
# **Reasoning**:
# The previous step identified that only the 'Income' column has missing values (24 missing values). Since the number of missing values is relatively small compared to the total number of rows (2240), imputation is a suitable strategy to avoid losing data. The median is a robust measure against outliers and is a reasonable choice for imputing income data.

# %%
df['Income'].fillna(df['Income'].median(), inplace=True)
print(df.isnull().sum())
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64
# /tmp/ipython-input-3406876094.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ## Verify missing values
#
# ### Subtask:
# Check if there are any remaining missing values after handling them.

# %% [markdown]
# **Reasoning**:
# Calculate the sum of missing values for each column in the DataFrame and print the result to verify if all missing values have been handled.

# %%
print(df.isnull().sum())
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Initially, the data was loaded incorrectly, treating all columns as one due to an incorrect delimiter.
# *   After correcting the delimiter to tab (`\t`), it was found that only the `Income` column had missing values, specifically 24 entries.
# *   The missing values in the `Income` column were successfully imputed using the median value of the existing income data.
# *   A final check confirmed that there are no remaining missing values in any column of the DataFrame.
#
# ### Insights or Next Steps
#
# *   The `Income` column, which contained missing values, now has a complete set of data, making it ready for further analysis or model training.
# *   Consider the impact of median imputation on the distribution and statistical properties of the `Income` column, especially if there are significant outliers.

# %%
df.drop_duplicates(inplace=True)
print(f"DataFrame shape after removing duplicates: {df.shape}")
# Out:
# DataFrame shape after removing duplicates: (2240, 29)

# %% [markdown]
# # Task
# Standardize text values in the dataframe from file "/content/marketing_campaign.csv".

# %% [markdown]
# ## Identify text columns
#
# ### Subtask:
# Identify columns in the DataFrame that contain text values.

# %% [markdown]
# **Reasoning**:
# Identify columns with object or string data types in the DataFrame to find text columns.

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        print(col)
# Out:
# Education
# Marital_Status
# Dt_Customer

# %% [markdown]
# ## Inspect unique values
#
# ### Subtask:
# For each text column, inspect the unique values to identify inconsistencies (e.g., variations in capitalization, spelling, or spacing).

# %% [markdown]
# **Reasoning**:
# Iterate through the identified text columns and print their unique values to inspect for inconsistencies.

# %%
text_columns = ['Education', 'Marital_Status', 'Dt_Customer']
for col in text_columns:
    print(f"Unique values in '{col}':")
    print(df[col].unique())
    print("-" * 30)
# Out:
# Unique values in 'Education':
# ['Graduation' 'PhD' 'Master' 'Basic' '2n Cycle']
# ------------------------------
# Unique values in 'Marital_Status':
# ['Single' 'Together' 'Married' 'Divorced' 'Widow' 'Alone' 'Absurd' 'YOLO']
# ------------------------------
# Unique values in 'Dt_Customer':
# ['04-09-2012' '08-03-2014' '21-08-2013' '10-02-2014' '19-01-2014'
#  '09-09-2013' '13-11-2012' '08-05-2013' '06-06-2013' '13-03-2014'
#  '15-11-2013' '10-10-2012' '24-11-2012' '24-12-2012' '31-08-2012'
#  '28-03-2013' '03-11-2012' '08-08-2012' '06-01-2013' '23-12-2012'
#  '11-01-2014' '18-03-2013' '02-01-2013' '27-05-2013' '20-02-2013'
#  '31-05-2013' '22-11-2013' '22-05-2014' '11-05-2013' '29-10-2012'
#  '29-08-2013' '31-12-2013' '02-09-2013' '11-02-2014' '01-02-2013'
#  '29-04-2013' '12-03-2013' '05-11-2013' '02-10-2013' '28-06-2014'
#  '09-11-2012' '24-05-2013' '01-01-2014' '08-11-2012' '12-05-2014'
#  '11-08-2012' '07-06-2014' '12-06-2013' '19-11-2012' '02-04-2013'
# ...

# %% [markdown]
# ## Standardize text values
#
# ### Subtask:
# Apply appropriate techniques to standardize the text values in each identified column (e.g., converting to lowercase, stripping whitespace, correcting spelling).

# %% [markdown]
# **Reasoning**:
# Define the list of text columns and then iterate through the list to apply lowercase and strip whitespace to each column.

# %%
text_columns = ['Education', 'Marital_Status', 'Dt_Customer']
for col in text_columns:
    df[col] = df[col].str.lower().str.strip()
print("Text columns standardized.")
# Out:
# Text columns standardized.

# %% [markdown]
# ## Verify standardization
#
# ### Subtask:
# Verify that the text values have been standardized correctly by re-inspecting the unique values.

# %% [markdown]
# **Reasoning**:
# Verify that the text values have been standardized correctly by re-inspecting the unique values.

# %%
text_columns = ['Education', 'Marital_Status', 'Dt_Customer']
for col in text_columns:
    print(f"Unique values in '{col}':")
    print(df[col].unique())
    print("-" * 30)
# Out:
# Unique values in 'Education':
# ['graduation' 'phd' 'master' 'basic' '2n cycle']
# ------------------------------
# Unique values in 'Marital_Status':
# ['single' 'together' 'married' 'divorced' 'widow' 'alone' 'absurd' 'yolo']
# ------------------------------
# Unique values in 'Dt_Customer':
# ['04-09-2012' '08-03-2014' '21-08-2013' '10-02-2014' '19-01-2014'
#  '09-09-2013' '13-11-2012' '08-05-2013' '06-06-2013' '13-03-2014'
#  '15-11-2013' '10-10-2012' '24-11-2012' '24-12-2012' '31-08-2012'
#  '28-03-2013' '03-11-2012' '08-08-2012' '06-01-2013' '23-12-2012'
#  '11-01-2014' '18-03-2013' '02-01-2013' '27-05-2013' '20-02-2013'
#  '31-05-2013' '22-11-2013' '22-05-2014' '11-05-2013' '29-10-2012'
#  '29-08-2013' '31-12-2013' '02-09-2013' '11-02-2014' '01-02-2013'
#  '29-04-2013' '12-03-2013' '05-11-2013' '02-10-2013' '28-06-2014'
#  '09-11-2012' '24-05-2013' '01-01-2014' '08-11-2012' '12-05-2014'
#  '11-08-2012' '07-06-2014' '12-06-2013' '19-11-2012' '02-04-2013'
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The text columns in the dataset were identified as `Education`, `Marital_Status`, and `Dt_Customer`.
# *   Initial inspection of unique values in these columns revealed no apparent inconsistencies in capitalization, spelling, or spacing.
# *   The standardization process involved converting the text values in the identified columns to lowercase and removing leading/trailing whitespace.
# *   Verification after standardization confirmed that the values in `Education` and `Marital_Status` were successfully converted to lowercase and stripped of whitespace. The unique values for `Dt_Customer` were also displayed, although the impact of lowercase and strip on date strings is minimal for standardization purposes here.
#
# ### Insights or Next Steps
#
# *   While basic standardization (lowercase and strip) was applied, further data cleaning or transformation might be needed depending on the downstream analysis (e.g., converting `Dt_Customer` to a proper datetime format).
# *   Since no spelling inconsistencies were found during the initial inspection, no spell correction was necessary for these columns. However, for datasets with potential spelling errors, additional techniques like fuzzy matching or dictionary lookups would be required.

# %% [markdown]
# # Task
# Load the CSV file "/content/marketing_campaign.csv" into a pandas DataFrame, convert the 'Dt_Customer' column to datetime objects, rename the columns to be clean and uniform, and ensure all columns have appropriate data types.

# %% [markdown]
# ## Convert date column to datetime
#
# ### Subtask:
# Convert the 'Dt_Customer' column to a consistent datetime format.

# %% [markdown]
# **Reasoning**:
# Convert the 'Dt_Customer' column to datetime objects using the specified format.

# %%
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'], format='%d-%m-%Y')
print(df['Dt_Customer'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# ## Rename columns
#
# ### Subtask:
# Rename the column headers to be clean and uniform.

# %% [markdown]
# **Reasoning**:
# Rename the columns using a dictionary mapping old names to new, clean names and then verify the changes by printing the column names.

# %%
new_column_names = {
    'ID': 'id',
    'Year_Birth': 'year_birth',
    'Education': 'education',
    'Marital_Status': 'marital_status',
    'Income': 'income',
    'Kidhome': 'kidhome',
    'Teenhome': 'teenhome',
    'Dt_Customer': 'dt_customer',
    'Recency': 'recency',
    'MntWines': 'mnt_wines',
    'MntFruits': 'mnt_fruits',
    'MntMeatProducts': 'mnt_meat_products',
    'MntFishProducts': 'mnt_fish_products',
    'MntSweetProducts': 'mnt_sweet_products',
    'MntGoldProds': 'mnt_gold_prods',
    'NumDealsPurchases': 'num_deals_purchases',
    'NumWebPurchases': 'num_web_purchases',
    'NumCatalogPurchases': 'num_catalog_purchases',
    'NumStorePurchases': 'num_store_purchases',
    'NumWebVisitsMonth': 'num_web_visits_month',
    'AcceptedCmp3': 'accepted_cmp3',
    'AcceptedCmp4': 'accepted_cmp4',
    'AcceptedCmp5': 'accepted_cmp5',
    'AcceptedCmp1': 'accepted_cmp1',
    'AcceptedCmp2': 'accepted_cmp2',
    'Complain': 'complain',
    'Z_CostContact': 'z_cost_contact',
    'Z_Revenue': 'z_revenue',
    'Response': 'response'
}
df.rename(columns=new_column_names, inplace=True)
print(df.columns)
# Out:
# Index(['id', 'year_birth', 'education', 'marital_status', 'income', 'kidhome',
#        'teenhome', 'dt_customer', 'recency', 'mnt_wines', 'mnt_fruits',
#        'mnt_meat_products', 'mnt_fish_products', 'mnt_sweet_products',
#        'mnt_gold_prods', 'num_deals_purchases', 'num_web_purchases',
#        'num_catalog_purchases', 'num_store_purchases', 'num_web_visits_month',
#        'accepted_cmp3', 'accepted_cmp4', 'accepted_cmp5', 'accepted_cmp1',
#        'accepted_cmp2', 'complain', 'z_cost_contact', 'z_revenue', 'response'],
#       dtype='object')

# %% [markdown]
# ## Check data types
#
# ### Subtask:
# Check the data types of all columns to ensure they are appropriate.

# %% [markdown]
# **Reasoning**:
# Print the data types of all columns to verify they are appropriate after previous transformations.

# %%
print(df.dtypes)
# Out:
# id                                int64
# year_birth                        int64
# education                        object
# marital_status                   object
# income                          float64
# kidhome                           int64
# teenhome                          int64
# dt_customer              datetime64[ns]
# recency                           int64
# mnt_wines                         int64
# mnt_fruits                        int64
# mnt_meat_products                 int64
# mnt_fish_products                 int64
# mnt_sweet_products                int64
# mnt_gold_prods                    int64
# num_deals_purchases               int64
# num_web_purchases                 int64
# num_catalog_purchases             int64
# num_store_purchases               int64
# num_web_visits_month              int64
# accepted_cmp3                     int64
# accepted_cmp4                     int64
# accepted_cmp5                     int64
# ...

# %% [markdown]
# ## Adjust data types (if necessary)
#
# ### Subtask:
# Convert any columns with incorrect data types to the appropriate type.

# %% [markdown]
# ## Verify data types
#
# ### Subtask:
# Verify that all columns have the correct data types.

# %% [markdown]
# **Reasoning**:
# Print the data types of all columns in the DataFrame to verify they are correct.

# %%
print(df.dtypes)
# Out:
# id                                int64
# year_birth                        int64
# education                        object
# marital_status                   object
# income                          float64
# kidhome                           int64
# teenhome                          int64
# dt_customer              datetime64[ns]
# recency                           int64
# mnt_wines                         int64
# mnt_fruits                        int64
# mnt_meat_products                 int64
# mnt_fish_products                 int64
# mnt_sweet_products                int64
# mnt_gold_prods                    int64
# num_deals_purchases               int64
# num_web_purchases                 int64
# num_catalog_purchases             int64
# num_store_purchases               int64
# num_web_visits_month              int64
# accepted_cmp3                     int64
# accepted_cmp4                     int64
# accepted_cmp5                     int64
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The 'Dt\_Customer' column was successfully converted to datetime objects with the `datetime64[ns]` data type.
# *   All column headers were successfully renamed to a clean and uniform format using lowercase and underscores.
# *   The data types for all columns were checked and found to be appropriate for the data they contain, including `int64`, `float64`, `object`, and `datetime64[ns]`.
#
# ### Insights or Next Steps
#
# *   The dataset is now well-structured with appropriate column names and data types, ready for further exploratory data analysis or modeling.
# *   The next step could involve handling missing values or outliers in the dataset before proceeding with analysis.
